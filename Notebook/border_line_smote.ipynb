# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
import warnings
warnings.filterwarnings('ignore')
print('Imported')
# Out:
# Imported

# %%
df = pd.read_csv(r'D:\Data Science\Data Science Projects\NASA_Near_Earth_Object_Detection\Data\neo_data.csv')
df.head()
# Out:
#         id               name  absolute_magnitude_h  min_diameter_km  \
# 0  2085990   85990 (1999 JV6)                 20.27         0.234723
# 1  2523915  523915 (1997 VM4)                 18.57         0.513517
# 2  3263533        (2004 XG29)                 25.66         0.019613
# 3  3426635          (2008 RU)                 22.40         0.088015
# 4  3601924        (2012 FO52)                 22.63         0.079169
#
#    max_diameter_km close_approach_date close_approach_date_full  \
# 0         0.524856          2015-01-05        2015-Jan-05 11:16
# 1         1.148259          2015-01-05        2015-Jan-05 11:56
# 2         0.043857          2015-01-05        2015-Jan-05 08:03
# 3         0.196807          2015-01-05        2015-Jan-05 08:11
# 4         0.177027          2015-01-05        2015-Jan-05 19:45
#
#    epoch_date_close_approach  relative_velocity_kps  miss_distance_km  \
# 0              1420456560000               7.694743      1.246329e+07
# ...

# %%
df.shape
# Out:
# (68005, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68005 entries, 0 to 68004
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         68005 non-null  int64
#  1   name                       68005 non-null  object
#  2   absolute_magnitude_h       68005 non-null  float64
#  3   min_diameter_km            68005 non-null  float64
#  4   max_diameter_km            68005 non-null  float64
#  5   close_approach_date        68005 non-null  object
#  6   close_approach_date_full   68005 non-null  object
#  7   epoch_date_close_approach  68005 non-null  int64
#  8   relative_velocity_kps      68005 non-null  float64
#  9   miss_distance_km           68005 non-null  float64
#  10  orbiting_body              68005 non-null  object
#  11  is_potentially_hazardous   68005 non-null  bool
#  12  is_sentry_object           68005 non-null  bool
# ...

# %%
df.describe()
# Out:
#                  id  absolute_magnitude_h  min_diameter_km  max_diameter_km  \
# count  6.800500e+04          68005.000000     68005.000000     68005.000000
# mean   2.863582e+07             24.383501         0.075923         0.169768
# std    2.536576e+07              2.605617         0.161152         0.360346
# min    2.000433e+06             10.400000         0.000683         0.001528
# 25%    3.748520e+06             22.610000         0.015155         0.033888
# 50%    3.989301e+06             24.600000         0.031956         0.071456
# 75%    5.430463e+07             26.220000         0.079902         0.178665
# max    5.454276e+07             32.950000        22.108281        49.435619
#
#        epoch_date_close_approach  relative_velocity_kps  miss_distance_km
# count               6.800500e+04           68005.000000      6.800500e+04
# mean                1.596132e+12              12.527878      3.183892e+07
# ...

# %%
df.head(2)
# Out:
#         id               name  absolute_magnitude_h  min_diameter_km  \
# 0  2085990   85990 (1999 JV6)                 20.27         0.234723
# 1  2523915  523915 (1997 VM4)                 18.57         0.513517
#
#    max_diameter_km close_approach_date close_approach_date_full  \
# 0         0.524856          2015-01-05        2015-Jan-05 11:16
# 1         1.148259          2015-01-05        2015-Jan-05 11:56
#
#    epoch_date_close_approach  relative_velocity_kps  miss_distance_km  \
# 0              1420456560000               7.694743      1.246329e+07
# 1              1420458960000              16.169622      5.815821e+07
#
#   orbiting_body  is_potentially_hazardous  is_sentry_object  \
# 0         Earth                      True             False
# 1         Earth                     False             False
#
#                                                      nasa_jpl_url
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2085990
# ...

# %%
df.drop(columns=['id', 'name', 'close_approach_date', 'close_approach_date_full', 'nasa_jpl_url', 'orbiting_body'], inplace=True)

# %%
df['diameter_range'] = df['max_diameter_km'] - df['min_diameter_km']
df.drop(columns=['min_diameter_km', 'max_diameter_km'], inplace=True)

# %%
cor = df[[x for x in df.columns if df[x].dtypes in ['int64', 'float64', 'bool']]].corr()
sns.heatmap(cor, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import mutual_info_classif
x = df.drop(columns=['is_potentially_hazardous'], axis=1)
y = df['is_potentially_hazardous']
mi_scores = mutual_info_classif(x, y)
feature_score = pd.Series(mi_scores, index = x.columns)
feature_score.sort_values().plot(kind='barh')
# Out:
# <Axes: >

# %%
x.columns
# Out:
# Index(['absolute_magnitude_h', 'epoch_date_close_approach',
#        'relative_velocity_kps', 'miss_distance_km', 'is_sentry_object',
#        'diameter_range'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x, y)
importance = pd.Series(model.feature_importances_, index=x.columns)
importance.sort_values().plot(kind='barh')
# Out:
# <Axes: >

# %%
num_cols = [col for col in x.columns if x[col].dtypes in ['float64', 'int64']]
cat_cols = [col for col in x.columns if x[col].dtypes in ['bool']]

# %%
cat_cols
# Out:
# ['is_sentry_object']

# %%
plt.figure(figsize=(10,6))
for idx, col in enumerate(num_cols, 1):
    plt.subplot(3,2,idx)
    sns.histplot(data=x, x=col, kde=True)
plt.tight_layout()
plt.show()

# %%
log_transformed_cols = [
    (np.log(x['diameter_range']), 'diameter_range_log'),
    (np.log(x['relative_velocity_kps']), 'relative_velocity_log'),
    (np.sqrt(x['miss_distance_km']), 'miss_distance_sqrt')
]

plt.figure(figsize=(10,4))
for idx, (col, name) in enumerate(log_transformed_cols, 1):
    plt.subplot(1,3,idx)
    plt.title(name)
    sns.histplot(col)
plt.tight_layout()
plt.show()

# %%
x['diameter_range'] = np.log(x['diameter_range'])
x['relative_velocity_kps'] = np.log(x['relative_velocity_kps'])
x['miss_distance_km'] = np.sqrt(x['miss_distance_km'])

# %%
plt.figure(figsize=(10,6))
plt.suptitle("Hist after transformation")
for idx, col in enumerate(num_cols, 1):
    plt.subplot(3,2,idx)
    sns.histplot(data=x, x=col, kde=True)
plt.tight_layout()
plt.show()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
preprocessor = ColumnTransformer([
    ('numerical columns', StandardScaler(), num_cols),
    ('categorical columns', OneHotEncoder(), cat_cols)
])
le = LabelEncoder()

# %%
y.value_counts()
# Out:
# is_potentially_hazardous
# False    64027
# True      3978
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((54404, 6), (13601, 6), (54404,), (13601,))

# %%
x_train_encoded = preprocessor.fit_transform(x_train)
x_test_encoded = preprocessor.transform(x_test)
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE()
x_res, y_res = smote.fit_resample(x_train_encoded, y_train_encoded)

# %%
x_res.shape, y_res.shape
# Out:
# ((102444, 7), (102444,))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

def evaluate_model(actual, predicted):
    accuracy = accuracy_score(actual, predicted)
    precision = precision_score(actual, predicted)
    f1 = f1_score(actual, predicted)
    recall = recall_score(actual, predicted)
    return accuracy, precision, f1, recall

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import (
    RandomForestClassifier, 
    GradientBoostingClassifier, 
    ExtraTreesClassifier, 
    AdaBoostClassifier
)

# %%
model_params = [
    ('Logistic Regression', LogisticRegression(), {
        'penalty': ['l1', 'l2', 'elasticnet', None],
        'C': [0.1, 0.3, 0.5, 0.7, 0.9],
        'solver': ['lbfgs', 'newton-cg', 'sag', 'saga'],
        'max_iter': [100, 300, 500, 700, 900]
    }),

    ('Decision Tree Classifier', DecisionTreeClassifier(), {
        'criterion': ['gini', 'entropy'],
        'splitter': ['best', 'random'],
        'max_depth': [x for x in range(1, 10, 2)],
        'min_samples_split': [x for x in range(2, 10, 2)],
        'min_samples_leaf': [x for x in range(1, 10, 3)],
        'max_features': ['sqrt', 'log2', None]
    }),

    ('Random Forest Classifier', RandomForestClassifier(), {
        'n_estimators': [x*100 for x in range(1, 10, 2)],
        'criterion': ['gini', 'entropy', 'log_loss'],
        'max_depth': [x for x in range(3, 10, 2)],
        'min_samples_split': [x for x in range(2, 10, 2)],
        'min_samples_leaf': [x for x in range(1, 10, 3)],
        'max_features': ['sqrt', 'log2', None]
    }),

    ('Gradient Boosting Classifier', GradientBoostingClassifier(), {
        'loss': ['log_loss', 'exponential'],
        'learning_rate': [x/10 for x in range(1, 10, 3)],
        'n_estimators': [x*100 for x in range(1, 10, 2)],
        'subsample': [x/10 for x in range(1, 10, 3)],
        'criterion': ['friedman_mse', 'squared_error'],
        'max_depth': [x for x in range(3, 10, 2)],
        'max_features': ['sqrt', 'log2']
    }),

    ('K Nearest Neighbors Classifier', KNeighborsClassifier(), {
        'n_neighbors': [x for x in range(1, 10, 3)],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
        'leaf_size': [x for x in range(30, 100, 20)],
        'p': [x for x in range(2, 10, 3)]
    }),

    ('Extra Trees Classifier', ExtraTreesClassifier(), {
        'n_estimators': [100, 200, 500, 1000],
        'criterion': ['gini', 'entropy'],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 5],
        'max_features': ['sqrt', 'log2', None]
    }),

    ('AdaBoost Classifier', AdaBoostClassifier(), {
        'n_estimators': [50, 100, 200, 500],
        'learning_rate': [0.01, 0.1, 0.5, 1.0],
        'algorithm': ['SAMME', 'SAMME.R']
    }),
]

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

scoring = {
    'f1': 'f1',
    'recall': 'recall',
    'precision': 'precision',
    'roc_auc': 'roc_auc',
    'average_precision': 'average_precision'
}

best_params_model = {}
trained_models = {}

# Step 1: Hyperparameter Tuning 
for model_name, model, params in model_params:
    print(f"Training {model_name} with Hyperparameter Tuning...\n")

    search = RandomizedSearchCV(
        estimator=model,
        param_distributions=params,
        scoring=scoring,            ## trying multiple scoring
        refit='average_precision',   
        cv=5,
        n_jobs=-1,
        verbose=2,
        n_iter=10  # Number of random iterations
    )

    # Fit the model
    search.fit(x_res, y_res)

    # Store best parameters and trained model
    best_params_model[model_name] = {
        "model_class": model.__class__,  # Store class, not instance
        "best_params": search.best_params_
    }
    trained_models[model_name] = search.best_estimator_

    print("=" * 100)
    print(f"{model_name} Hyperparameter tuning completed. Best Params: {search.best_params_}")
    print("=" * 100)
# Out:
# Training Logistic Regression with Hyperparameter Tuning...
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ...
# Logistic Regression Hyperparameter tuning completed. Best Params: {'solver': 'newton-cg', 'penalty': None, 'max_iter': 500, 'C': 0.1}
# ...
# Training Decision Tree Classifier with Hyperparameter Tuning...
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ...
# Decision Tree Classifier Hyperparameter tuning completed. Best Params: {'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 'log2', 'max_depth': 7, 'criterion': 'entropy'}
# ...
# Training Random Forest Classifier with Hyperparameter Tuning...
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ...
# Random Forest Classifier Hyperparameter tuning completed. Best Params: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'max_depth': 9, 'criterion': 'gini'}
# ...

# %%
model_performance = []

# Train models with best hyperparameters
for model_name, values in best_params_model.items():
    model_class = values["model_class"]
    best_params = values["best_params"]

    # Instantiate model with best hyperparameters
    model = model_class(**best_params)
    trained_models[model_name] = model  # Store trained model

    # Train the model
    model.fit(x_res, y_res)

    # Make predictions
    y_pred = model.predict(x_test_encoded)

    # Evaluate the model
    test_accuracy, test_precision, test_f1, test_recall = evaluate_model(y_test_encoded, y_pred)

    # Store results
    model_performance.append({
        "Model": model_name,
        "Accuracy": np.round(test_accuracy, 4),
        "Precision": np.round(test_precision, 4),
        "F1-score": np.round(test_f1, 4),
        "recall-score" : np.round(test_recall, 4)
    })

    # Print performance metrics
    print(f"Model: {model_name}")
    print(f"Accuracy: {test_accuracy:.2f}, Precision: {test_precision:.2f}, Recall: {test_recall:.2f}, F1-score: {test_f1:.2f}")
    print("=" * 50)
# Out:
# Model: Logistic Regression
# Accuracy: 0.85, Precision: 0.28, Recall: 0.98, F1-score: 0.44
# ...
# Model: Decision Tree Classifier
# Accuracy: 0.87, Precision: 0.30, Recall: 0.99, F1-score: 0.46
# ...
# Model: Random Forest Classifier
# Accuracy: 0.87, Precision: 0.31, Recall: 0.98, F1-score: 0.47
# ...
# Model: Gradient Boosting Classifier
# Accuracy: 0.92, Precision: 0.40, Recall: 0.70, F1-score: 0.51
# ...
# Model: K Nearest Neighbors Classifier
# Accuracy: 0.90, Precision: 0.35, Recall: 0.80, F1-score: 0.49
# ...
# Model: Extra Trees Classifier
# Accuracy: 0.88, Precision: 0.32, Recall: 0.96, F1-score: 0.48
# ...
# Model: AdaBoost Classifier
# Accuracy: 0.87, Precision: 0.31, Recall: 0.99, F1-score: 0.47
# ...

# %%
performance_df = pd.DataFrame(model_performance)
performance_df
# Out:
#                             Model  Accuracy  Precision  F1-score  recall-score
# 0             Logistic Regression    0.8530     0.2820    0.4377        0.9774
# 1        Decision Tree Classifier    0.8671     0.3041    0.4649        0.9862
# 2        Random Forest Classifier    0.8722     0.3114    0.4724        0.9774
# 3    Gradient Boosting Classifier    0.9210     0.3999    0.5082        0.6972
# 4  K Nearest Neighbors Classifier    0.9016     0.3506    0.4874        0.7990
# 5          Extra Trees Classifier    0.8782     0.3205    0.4812        0.9648
# 6             AdaBoost Classifier    0.8682     0.3058    0.4668        0.9862

# %%
best_model_name = performance_df.loc[performance_df["recall-score"].idxmax(), "Model"]
best_model_name
# Out:
# 'Decision Tree Classifier'

# %%
best_model_params = [{} if best_model_name in {"CatBoost", "XGBoost Classifier"} else best_params_model[best_model_name]["best_params"]][0]
best_model_params
# Out:
# {'splitter': 'best',
#  'min_samples_split': 4,
#  'min_samples_leaf': 7,
#  'max_features': 'log2',
#  'max_depth': 7,
#  'criterion': 'entropy'}

# %%
best_model_class = best_params_model[best_model_name]["model_class"]
best_model = best_model_class(**best_model_params)
best_model
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='log2',
#                        min_samples_leaf=7, min_samples_split=4)

# %%
best_model.fit(x_res, y_res)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features='log2',
#                        min_samples_leaf=7, min_samples_split=4)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
cv_score = cross_val_score(best_model, x_res, y_res, scoring='f1', cv=kfold)

# %%
print(f'We get the mean cross validation score = {round(np.mean(cv_score), 2)}')
# Out:
# We get the mean cross validation score = 0.93

# %%
preds = best_model.predict(x_test_encoded)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test_encoded, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93     12805
#            1       0.31      0.97      0.47       796
#
#     accuracy                           0.87     13601
#    macro avg       0.65      0.92      0.70     13601
# weighted avg       0.96      0.87      0.90     13601
